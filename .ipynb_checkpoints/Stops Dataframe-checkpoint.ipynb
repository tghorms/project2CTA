# %%
import pandas as pd
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import time 
from sqlalchemy import create_engine
import numpy as np

# %%
file_to_load = "list_of_stops.csv"
stops_data = pd.read_csv(file_to_load)
stops_data.head()
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location
# 0  (41.857908, -87.669147)
# 1  (41.857908, -87.669147)
# 2  (41.829353, -87.680622)
# 3  (41.829353, -87.680622)
# 4  (41.831677, -87.625826)

# %%
stops_df = stops_data[["STOP_ID", "STOP_NAME", "STATION_NAME", "STATION_DESCRIPTIVE_NAME", "MAP_ID", "Location"]]
stops_df.head()
# Out:
#    STOP_ID                        STOP_NAME          STATION_NAME  \
# 0    30162         18th (54th/Cermak-bound)                  18th
# 1    30161                18th (Loop-bound)                  18th
# 2    30022         35th/Archer (Loop-bound)           35th/Archer
# 3    30023       35th/Archer (Midway-bound)           35th/Archer
# 4    30214  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#             STATION_DESCRIPTIVE_NAME  MAP_ID                 Location
# 0                   18th (Pink Line)   40830  (41.857908, -87.669147)
# 1                   18th (Pink Line)   40830  (41.857908, -87.669147)
# 2          35th/Archer (Orange Line)   40120  (41.829353, -87.680622)
# 3          35th/Archer (Orange Line)   40120  (41.829353, -87.680622)
# 4  35th-Bronzeville-IIT (Green Line)   41120  (41.831677, -87.625826)

# %%
stops_df[["Lat","Lon"]] = stops_df.Location.str.split(",", expand=True,)


stops_df.head()
# Out:
#    STOP_ID                        STOP_NAME          STATION_NAME  \
# 0    30162         18th (54th/Cermak-bound)                  18th
# 1    30161                18th (Loop-bound)                  18th
# 2    30022         35th/Archer (Loop-bound)           35th/Archer
# 3    30023       35th/Archer (Midway-bound)           35th/Archer
# 4    30214  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#             STATION_DESCRIPTIVE_NAME  MAP_ID                 Location  \
# 0                   18th (Pink Line)   40830  (41.857908, -87.669147)
# 1                   18th (Pink Line)   40830  (41.857908, -87.669147)
# 2          35th/Archer (Orange Line)   40120  (41.829353, -87.680622)
# 3          35th/Archer (Orange Line)   40120  (41.829353, -87.680622)
# 4  35th-Bronzeville-IIT (Green Line)   41120  (41.831677, -87.625826)
#
#           Lat           Lon
# 0  (41.857908   -87.669147)
# 1  (41.857908   -87.669147)
# 2  (41.829353   -87.680622)
# 3  (41.829353   -87.680622)
# 4  (41.831677   -87.625826)

# %%
stops_df = stops_df.drop(columns=['Location'])

stops_df.head()
# Out:
#    STOP_ID                        STOP_NAME          STATION_NAME  \
# 0    30162         18th (54th/Cermak-bound)                  18th
# 1    30161                18th (Loop-bound)                  18th
# 2    30022         35th/Archer (Loop-bound)           35th/Archer
# 3    30023       35th/Archer (Midway-bound)           35th/Archer
# 4    30214  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#             STATION_DESCRIPTIVE_NAME  MAP_ID         Lat           Lon
# 0                   18th (Pink Line)   40830  (41.857908   -87.669147)
# 1                   18th (Pink Line)   40830  (41.857908   -87.669147)
# 2          35th/Archer (Orange Line)   40120  (41.829353   -87.680622)
# 3          35th/Archer (Orange Line)   40120  (41.829353   -87.680622)
# 4  35th-Bronzeville-IIT (Green Line)   41120  (41.831677   -87.625826)

# %%
stops_df['Lat'] = stops_df.Lat.str.replace("(", "")
stops_df['Lon'] = stops_df.Lon.str.replace(")", "")

# %%
stops_df.head()
# Out:
#    STOP_ID                        STOP_NAME          STATION_NAME  \
# 0    30162         18th (54th/Cermak-bound)                  18th
# 1    30161                18th (Loop-bound)                  18th
# 2    30022         35th/Archer (Loop-bound)           35th/Archer
# 3    30023       35th/Archer (Midway-bound)           35th/Archer
# 4    30214  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#             STATION_DESCRIPTIVE_NAME  MAP_ID        Lat          Lon
# 0                   18th (Pink Line)   40830  41.857908   -87.669147
# 1                   18th (Pink Line)   40830  41.857908   -87.669147
# 2          35th/Archer (Orange Line)   40120  41.829353   -87.680622
# 3          35th/Archer (Orange Line)   40120  41.829353   -87.680622
# 4  35th-Bronzeville-IIT (Green Line)   41120  41.831677   -87.625826

# %%
rds_connection_string = "postgres:taylormade@localhost:5432/CTA"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
stops_df.to_sql(name='stops_table', con=engine, if_exists='append', index=False)

# %%
CTA = pd.read_sql_query('select * from stops_table', con=engine).head()

# %%
CTA.to_html("Data.html")
